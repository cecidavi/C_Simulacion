# %%
import pandas as pd

# %%
ruta_excel = r"C:\Users\cecir\OneDrive\Documentos\Simulacion\CAlcular pi con montecarlo\PROYECCION ESTIMACION alumnos.xlsx"

Datos_de_educacion_df = pd.read_excel(ruta_excel)

Datos_de_educacion_df.head(20)
# Out:
#                     Nivel Educativo  Alumnos 18-19  Alumnos 19-20  \
# 0              INICIAL ESCOLARIZADO        15635.0         9692.0
# 1           INICIAL NO ESCOLARIZADA         8537.0         9440.0
# 2                      ESPECIAL CAM         3371.0         3511.0
# 3                    ESPECIAL USAER        37292.0        37470.0
# 4                PREESCOLAR GENERAL       121192.0       125965.0
# 5            PREESCOLAR COMUNITARIO         2426.0         2626.0
# 6                  PRIMARIA GENERAL       336772.0       338239.0
# 7              PRIMARIA COMUNITARIO          341.0          334.0
# 8                       SECUNDARIAS       154055.0       154209.0
# 9            SECUNDARIA COMUNITARIO          127.0          134.0
# 10        FORMACIÓN PARA EL TRABAJO        53863.0        46860.0
# 11  EDUCACI&Oacute;N MEDIA SUPERIOR       141259.0       137212.0
# 12        EDUCACI&Oacute;N SUPERIOR       116016.0       124677.0
# ...
